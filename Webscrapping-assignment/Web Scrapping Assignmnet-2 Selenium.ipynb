# %%
! pip install selenium

# %%
#importing all the required libraries
import selenium
from selenium import webdriver
import time
import pandas as pd
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException,ElementNotInteractableException,InvalidArgumentException,InvalidCookieDomainException

# %%
driver = webdriver.Chrome(r"C:\Users\Gupta's\Downloads\chromedriver_win32/chromedriver.exe")

# %% [markdown]
# # Q1: Write a python program to scrape data for “Data Analyst” Job position in “Bangalore” location. You have to scrape the job-title, job-location, company_name, experience_required. You have to scrape first 10 jobs data.

# %%
# load the website

url='https://www.naukri.com/'
driver.get(url)

# %%
#Calling driver to load the website
search_job=driver.find_element_by_id('qsb-keyword-sugg')
search_job.send_keys('Data Analyst')
search_loc=driver.find_element_by_id('qsb-location-sugg')
search_loc.send_keys('Bangalore')
button_clk=driver.find_element_by_class_name('search-btn')
button_clk.click()

# %%
#Searching the target webpage element
titles_job=driver.find_elements_by_xpath("//a[@class='title fw500 ellipsis']")
job_title=[]
for i in titles_job:
    job_title.append(i.text)
job_title=job_title[0:10]

title_loc=driver.find_elements_by_xpath("//li[@class='fleft grey-text br2 placeHolderLi location']")
job_loc=[]
for i in title_loc:
    job_loc.append(i.text)
job_loc=job_loc[0:10]

title_company=driver.find_elements_by_xpath("//a[@class='subTitle ellipsis fleft']")
com_name=[]
for i in title_company:
    com_name.append(i.text)
com_name=com_name[0:10]

title_exp=driver.find_elements_by_xpath("//li[@class='fleft grey-text br2 placeHolderLi experience']")
can_exp=[]
for i in title_exp:
    can_exp.append(i.text)
can_exp=can_exp[0:10]

# %%
#Creating Dataframe
Data_analyst=pd.DataFrame({})
Data_analyst['Job-Title']=job_title
Data_analyst['Job-Location']=job_loc
Data_analyst['Company_Name']=com_name
Data_analyst['Experience_Required']=can_exp
Data_analyst

# %% [markdown]
# # Q2: Write a python program to scrape data for “Data Scientist” Job position in “Bangalore” location. You have to scrape the job-title, job-location, company_name, full job-description. You have to scrape first 10 jobs data.

# %%
#Calling driver to load the website
url='https://www.naukri.com/'
driver.get(url)

#Calling driver to load the website
search_job=driver.find_element_by_id('qsb-keyword-sugg')
search_job.send_keys('Data Scientist')
search_loc=driver.find_element_by_id('qsb-location-sugg')
search_loc.send_keys('Bangalore')
button_clk=driver.find_element_by_class_name('search-btn')
button_clk.click()

# %%
#Searching the target webpage element
titles_job=driver.find_elements_by_xpath("//a[@class='title fw500 ellipsis']")
job_title=[]
for i in titles_job:
    job_title.append(i.text)
job_title=job_title[0:10]

title_loc=driver.find_elements_by_xpath("//li[@class='fleft grey-text br2 placeHolderLi location']")
job_loc=[]
for i in title_loc:
    job_loc.append(i.text)
job_loc=job_loc[0:10]

title_company=driver.find_elements_by_xpath("//a[@class='subTitle ellipsis fleft']")
com_name=[]
for i in title_company:
    com_name.append(i.text)
com_name=com_name[0:10]

title_desc=driver.find_elements_by_xpath("//div[@class='job-description fs12 grey-text']")
job_desc=[]
for i in title_desc:
    job_desc.append(i.text)
job_desc=job_desc[0:10]

# %%
#Creating Dataframe
Data_Scientist=pd.DataFrame({})
Data_Scientist['Job-Title']=job_title
Data_Scientist['Job-Location']=job_loc
Data_Scientist['Company_Name']=com_name
Data_Scientist['Job-Description']=job_desc
Data_Scientist
# Out:
# Empty DataFrame
# Columns: [Job-Title, Job-Location, Company_Name, Job-Description]
# Index: []

# %% [markdown]
# # Q3: In this question you have to scrape data using the filters available on the webpage as shown below:

# %%
#Calling driver to load the website
url='https://www.naukri.com/'
driver.get(url)

# %%
#Calling driver to load the website
search_job=driver.find_element_by_id('qsb-keyword-sugg')
search_job.send_keys('Data Scientist')
button_clk=driver.find_element_by_class_name('search-btn')
button_clk.click()

# %%
buttom_clk=driver.find_elements_by_xpath("//span[@class='ellipsis fleft']")
for i in buttom_clk:
    if i.text == 'Delhi / NCR':   
        i.click()
        break

# %%
butto_clk=driver.find_elements_by_xpath("//span[@class='ellipsis fleft']")
for i in butto_clk:
    if i.text == '3-6 Lakhs':   
        i.click()
        break

# %%
#Searching the target webpage targeted element
titles_job=driver.find_elements_by_xpath("//a[@class='title fw500 ellipsis']")
job_title=[]
for i in titles_job:
    job_title.append(i.text)
job_title=job_title[0:10]

title_loc=driver.find_elements_by_xpath("//li[@class='fleft grey-text br2 placeHolderLi location']")
job_loc=[]
for i in title_loc:
    job_loc.append(i.text)
job_loc=job_loc[0:10]

title_company=driver.find_elements_by_xpath("//a[@class='subTitle ellipsis fleft']")
com_name=[]
for i in title_company:
    com_name.append(i.text)
com_name=com_name[0:10]

title_exp=driver.find_elements_by_xpath("//li[@class='fleft grey-text br2 placeHolderLi experience']")
can_exp=[]
for i in title_exp:
    can_exp.append(i.text)
can_exp=can_exp[0:10]

# %%
#Creating Dataframe
Data_Scientist=pd.DataFrame({})
Data_Scientist['Job-Title']=job_title
Data_Scientist['Job-Location']=job_loc
Data_Scientist['Company_Name']=com_name
Data_Scientist['Experience_Required']=can_exp
Data_Scientist
# Out:
#                                            Job-Title  \
# 0                              Senior Data Scientist
# 1  Job Opportunity || Data Scientist || HCL Techn...
# 2  Data Scientist/Senior Data Scientist - IT Serv...
# 3                              Senior Data Scientist
# 4                                     Data Scientist
# 5                              Senior Data Scientist
# 6                   Data Scientist - Sales Analytics
# 7          Data Scientist - SQL/Predictive Analytics
# 8  Co-Founder & Principal Data Scientist/Senior S...
# 9  Data Scientist / Machine Learning Engineer - P...
#
#                                         Job-Location  \
# 0                         Noida, Bangalore/Bengaluru
# 1                                        Delhi / NCR
# 2  Hyderabad/Secunderabad, Pune, Gurgaon/Gurugram...
# 3             Noida, Hyderabad/Secunderabad, Chennai
# 4              Gurgaon/Gurugram, Bangalore/Bengaluru
# 5                                              Noida
# ...

# %% [markdown]
# # Q4: Write a python program to scrape data for first 10 job results for Data scientist Designation in Noida location. You have to scrape company_name, No. of days ago when job was posted, Rating of the company

# %%
warnings.filterwarnings("ignore")
driver = webdriver.Chrome(r"C:\Users\Gupta's\Downloads\chromedriver_win32/chromedriver.exe")
my_page=driver.get('https://www.glassdoor.co.in/index.htm')

# %%
# Now entering “Data Scientist” in “Job Title, Keywords or Company” field and enter “Noida” in “location” field.

search_field_designation=driver.find_element_by_xpath("//div[@class='d-flex flex-row align-items-center']//div[1]//div[1]//input")  #job search bar
search_field_designation.send_keys("Data Scientist")

time.sleep(2)
search_field_location=driver.find_element_by_xpath("//div[@class='d-flex flex-row align-items-center']//div[3]//div[1]//input")  #location search bar
search_field_location.clear()   # clearing job location search_bar
search_field_location.send_keys("Noida")

time.sleep(2)
# clicking the search button
search_button=driver.find_element_by_xpath("//button[@class='gd-ui-button ml-std col-auto SearchStyles__newSearchButton css-iixdfr']")
search_button.click()


# creating empty lists for scraping data
company_ratings=[]
company_name=[]
days_ago=[]


time.sleep(3)
# finding the element where company name is present
companies=driver.find_elements_by_xpath("//div[@class='d-flex justify-content-between align-items-start']/a")
for i in companies:
    if i.text is None :
        company_name.append("--") 
    else:
        company_name.append(i.text)

        
time.sleep(3)        
# finding the element where ratings of the company  is present
ratings=driver.find_elements_by_xpath("//span[@class='css-19pjha7 e1cjmv6j1']")
for i in ratings:
    if i.text is None :
        company_ratings.append("--") 
    else:
        company_ratings.append(i.text)
        

time.sleep(3)
# finding the element where  No. of days ago when job was posted is present
days=driver.find_elements_by_xpath("//div[@class='d-flex align-items-end pl-std css-mi55ob']")
for i in days:
    if i.text is None :
        days_ago.append("--") 
    else:
        days_ago.append(i.text)
        
        
time.sleep(3)        
 # creating the dataframe from the scraped data and taking only first 10 jobs
df=pd.DataFrame({"company_name":company_name[0:10],"company_ratings":company_ratings[0:10],"days_ago":days_ago[0:10]})
df
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-197-56af998a51ad> in <module>
#       1 # Now entering “Data Scientist” in “Job Title, Keywords or Company” field and enter “Noida” in “location” field.
#       2
# ----> 3 search_field_designation=driver.find_element_by_xpath("//div[@class='d-flex flex-row align-items-center']//div[1]//div[1]//input")  #job search bar
#       4 search_field_designation.send_keys("Data Scientist")
#       5
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element_by_xpath(self, xpath)
#     392             element = driver.find_element_by_xpath('//div/td[1]')
#     393         """
# --> 394         return self.find_element(by=By.XPATH, value=xpath)
#     395
#     396     def find_elements_by_xpath(self, xpath):
#
# ...

# %% [markdown]
# # Q5: Write a python program to scrape the salary data for Data Scientist designation in Noida location.

# %%
driver = webdriver.Chrome(r"C:\Users\Gupta's\Downloads\chromedriver_win32/chromedriver.exe")

# %%
url='https://www.glassdoor.co.in/Job/Home/recentActivity.htm'
driver.get(url)

# %%
#Calling driver to load the website
job_search=driver.find_element_by_id('sc.keyword')
job_search.send_keys("Data Scientist")

# %%
loc_search=driver.find_element_by_id('sc.location')
loc_search.clear()
loc_search.send_keys("Noida")

# %%
button_clk=driver.find_element_by_xpath("//button[@class='gd-ui-button ml-std col-auto SearchStyles__newSearchButton css-iixdfr']")
button_clk.click()

# %%
#Searching the target webpage targeted element
title_company=driver.find_elements_by_xpath("//a[@class=' css-l2wjgv e1n63ojh0 jobLink']")
com_name=[]
for i in title_company:
    com_name.append(i.text)
com_name=com_name[0:10]

title_days=driver.find_elements_by_xpath("//div[@class='d-flex align-items-end pl-std css-mi55ob']")
No_days=[]
for i in title_days:
    No_days.append(i.text)
No_days=No_days[0:10]

title_rating=driver.find_elements_by_xpath("//span[@class='css-19pjha7 e1cjmv6j1']")
com_ratings=[]
for i in title_rating:
    com_ratings.append(i.text)
com_ratings=com_ratings[0:10]

# %%
#Creating Dataframe
Data_Scientist=pd.DataFrame({})
Data_Scientist['Company_Name']=com_name
Data_Scientist['No. of daysago when job was posted']=No_days
Data_Scientist[' Rating of the company']=com_ratings
Data_Scientist

# %% [markdown]
# # Q6 : Scrape data of first 100 sunglasses listings on flipkart.com. You have to scrape four attributes:

# %%
#Calling driver to load the website
url='https://www.flipkart.com/'
driver.get(url)

# %%
#Calling driver to load the website
glass_search=driver.find_element_by_xpath("//div[@class='_3OO5Xc']/input")
glass_search.send_keys("sunglasses")

button_clk=driver.find_element_by_xpath("//button[@class='L0Z3Pu']")
button_clk.click()

# %%
page_url=[]

url=driver.find_elements_by_xpath("//nav[@class='yFHi8N']//a")
for i in url:
    page_url.append(i.get_attribute('href'))
page_url=page_url[0:3]

# %%
#Searching the target webpage targeted element
brand_title=[]
brand_Description=[]
brand_Price=[]
brand_Discount=[] 

for i in page_url:
    driver.get(i)
    titles_brand=driver.find_elements_by_xpath("//div[@class='_2WkVRV']")
    for i in titles_brand:
        brand_title.append(i.text)
        
    titles_Description=driver.find_elements_by_xpath("//a[@class='IRpwTa']")
    for i in titles_Description:
        brand_Description.append(i.text)
        
    titles_Price=driver.find_elements_by_xpath("//div[@class='_30jeq3']")
    for i in titles_Price:
        brand_Price.append(i.text)
        
    titles_Discount=driver.find_elements_by_xpath("//div[@class='_3Ay6Sb']/span")
    for i in titles_Discount:
        brand_Discount.append(i.text)

# %%
#Creating Dataframe
flipkart=pd.DataFrame({})
flipkart['Brand']=brand_title[0:100]
flipkart['Product Description']=brand_Description[0:100]
flipkart['Price']=brand_Price[0:100]
flipkart['Discount %']=brand_Discount[0:100]

pd.set_option("display.max_rows", None)
flipkart.head(100)
# Out:
#                         Brand  \
# 0                    Fastrack
# 1                      PIRASO
# 2                      PIRASO
# 3                   Elligator
# 4                    Fastrack
# 5           SHAAH COLLECTIONS
# 6                    Fastrack
# 7                      PIRASO
# 8                   New Specs
# 9                    Fastrack
# 10             ROZZETTA CRAFT
# 11               Singco India
# 12                  Elligator
# 13                   Fastrack
# 14                   Fastrack
# 15                   Fastrack
# 16             kingsunglasses
# 17                  Rich Club
# 18               Singco India
# 19                   Fastrack
# 20                 PHENOMENAL
# 21                      NuVew
# 22          SHAAH COLLECTIONS
# 23                   Fastrack
# 24             kingsunglasses
# 25                   Fastrack
# 26          SHAAH COLLECTIONS
# 27             kingsunglasses
# 28                     GANSTA
# 29                     GANSTA
# ...

# %% [markdown]
# # Q7: Scrape 100 reviews data from flipkart.com for iphone11 phone. You have to go the link: https://www.flipkart.com/apple-iphone-11-black-64-gb-includesearpods-poweradapter/p/itm0f37c2240b217?pid=MOBFKCTSVZAXUHGR&lid=LSTMOBFKCTSVZAXUHGREPBFGI&marketplace.

# %%
driver = webdriver.Chrome(r"C:\Users\Gupta's\Downloads\chromedriver_win32/chromedriver.exe")

# %%
#Calling driver to load the website
url='https://www.flipkart.com/apple-iphone-11-black-64-gb-includesearpods-poweradapter/p/itm0f37c2240b217?pid=MOBFKCTSVZAXUHGR&lid=LSTMOBFKCTSVZAXUHGREPBFGI&marketplace.'
driver.get(url)

# %%
driver.find_element_by_xpath("//div[@class='_3UAT2v _16PBlm']/span").click()

# %%
#Searching the target webpage targeted element
import time
Rating = []
Review_summary = []
Full_review = []

#Scraping 100 Reviews
while True:
    time.sleep(3)
    
    for i in driver.find_elements_by_xpath("//div[@class = 'col _2wzgFH K0kLPL']/div[@class= 'row']/div"):
        Rating.append(i.text)
        if len(Rating) == 200:
            break 
            
    for i in driver.find_elements_by_xpath("//div[@class= 'row']//p[@class = '_2-N8zT']"):
        Review_summary.append(i.text)
        if len(Review_summary) == 100:
            break 
            
    for i in driver.find_elements_by_xpath("//div[@class= 't-ZTKy']//div[@class]"):
        Full_review.append(i.text.replace('\n',''))
        if len(Full_review) == 100:
            break 
        
    if len(Full_review) == 100:
        break    
                
    for i in driver.find_elements_by_xpath("//nav[@class='yFHi8N']//a[@class='_1LKTO3']"):
        next_page_1=[i.get_attribute("href")]
    
    time.sleep(3)
    
    for n in next_page_1:
        driver.get(n)

driver.close()

# %%
Ratings = []
for i in range(0,len(Rating)):
    if i == 0 or  i/2 == i//2:
        Ratings.append(Rating[i])

# %%
#Creating Dataframe
flipkart=pd.DataFrame({})
flipkart['Rating']=Ratings
flipkart['Review_summary']=Review_summary
flipkart['Full_review']=Full_review

pd.set_option("display.max_colwidth",None)
flipkart
# Out:
#    Rating         Review_summary  \
# 0       5              Brilliant
# 1       5         Simply awesome
# 2       5       Perfect product!
# 3       5              Fabulous!
# 4       5    Best in the market!
# 5       5      Worth every penny
# 6       5          Great product
# 7       4            Good choice
# 8       5      Worth every penny
# 9       5     Highly recommended
# 10      5     Highly recommended
# 11      5       Perfect product!
# 12      5       Perfect product!
# 13      5         Classy product
# 14      5      Worth every penny
# 15      5       Perfect product!
# 16      5     Highly recommended
# 17      5         Simply awesome
# 18      5      Worth every penny
# 19      5               Terrific
# 20      5      Worth every penny
# 21      5              Wonderful
# 22      4           Nice product
# 23      5       Perfect product!
# 24      5         Classy product
# 25      5              Brilliant
# 26      5              Must buy!
# ...

# %% [markdown]
# # Q8: Scrape data for first 100 sneakers you find when you visit flipkart.com and search for “sneakers” in the search field.

# %%
driver = webdriver.Chrome(r"C:\Users\Gupta's\Downloads\chromedriver_win32/chromedriver.exe")

# %%
#Calling driver to load the website
driver.get("https://www.flipkart.com/")
driver.maximize_window()

#Closing the Login Pop-up
time.sleep(3)
pop_up = driver.find_element_by_xpath("//div[@class='_2QfC02']/button[@class = '_2KpZ6l _2doB4z']")
pop_up.click()

product_search = driver.find_element_by_xpath("//div[@class='_3OO5Xc']//input[@type = 'text']")
product_search.send_keys("sneakers")

search_button = driver.find_element_by_xpath("//div[@class = 'col-12-12 _2oO9oE']//button[@class = 'L0Z3Pu']")
search_button.click()

# %%
#Creating lists for attributes
Brand_1 = []
Product_1= []
Price_1 = []
Discount_1 =[]

#Scraping 100 sneakers data
while True:
    
    time.sleep(3)
        
    for i in driver.find_elements_by_xpath("//div[@class= '_2B099V']//div[@class = '_2WkVRV']"):
        Brand_1.append(i.text)
        if len(Brand_1) == 100:
            break
    
    for i in driver.find_elements_by_xpath("//div[@class= '_2B099V']//a"):
        Product_1.append(i.get_attribute('title'))
        if len(Product_1) == 200:
            break
    
    for i in driver.find_elements_by_xpath("//div[@class= '_25b18c']//div[@class = '_30jeq3']"):
        Price_1.append(i.text) 
        if len(Price_1) == 100:
            break    
    for i in driver.find_elements_by_xpath("//div[@class= '_3Ay6Sb']/span"):
        Discount_1.append(i.text)
        if len(Discount_1) == 100:
            break  
            
    if len(Discount_1) == 100:
        break
        
    for j in driver.find_elements_by_xpath("//nav[@class ='yFHi8N']/a[@class = '_1LKTO3']"):
        next_page_2=[j.get_attribute("href")]
    
    time.sleep(3)
        
    for n in next_page_2:
        driver.get(n) 
    
driver.close()

# %%
#Shortening Product Description by removing unwanted datas
Product_Desc = []
for i in range(0,len(Product_1)):
    if i == 0 or  i/2 == i//2:
        Product_Desc.append(Product_1[i])

# %%
flipkart=pd.DataFrame({})
flipkart['Brand']=Brand_1
flipkart['Product Description']=Product_Desc
flipkart['Price']=Price_1
flipkart['Discount']=Discount_1

flipkart
# Out:
#               Brand  \
# 0            BRUTON
# 1        D-SNEAKERZ
# 2            BRUTON
# 3          Magnolia
# 4      Robbie jones
# 5             BIRDE
# 6    luxury fashion
# 7           Numenzo
# 8           Numenzo
# 9            Kraasa
# 10        India hub
# 11            BIRDE
# 12        bluemaker
# 13         HOTSTYLE
# 14         ASTEROID
# 15          Numenzo
# 16          believe
# 17     Robbie jones
# 18          Edoeviv
# 19     Robbie jones
# 20           Chevit
# 21        SCATCHITE
# 22            Zsyto
# 23           BRUTON
# 24          ESSENCE
# 25            SPARX
# 26     Robbie jones
# 27            SPARX
# 28           Chevit
# 29           BRUTON
# 30        bluemaker
# 31       Shoes Bank
# 32           Chevit
# 33    RODDICK SHOES
# 34         HOTSTYLE
# 35        India hub
# 36   luxury fashion
# 37        bluemaker
# 38           Chevit
# 39        bluemaker
# 40            Arohi
# 41          Numenzo
# 42              HOC
# 43            Creer
# ...

# %% [markdown]
# # Q9: Go to the link - https://www.myntra.com/shoes Set Price filter to “Rs. 6649 to Rs. 13099” , Color filter to “Black”, as shown in the below image

# %%
driver = webdriver.Chrome(r"C:\Users\Gupta's\Downloads\chromedriver_win32/chromedriver.exe")

# %%
#Calling the driver to load the website
driver.get("https://www.myntra.com/shoes")
driver.maximize_window()

time.sleep(3)
#selecting black color.
filter_1 = driver.find_elements_by_xpath("//li[@class ='colour-listItem']//label[@class ='common-customCheckbox']/div[@class = 'common-checkboxIndicator']") 
filter_1[0].click()

time.sleep(5)
#setting price filter
filter_2 = driver.find_elements_by_xpath("//ul[@class ='price-list']//label[@class ='common-customCheckbox vertical-filters-label']/div[@class = 'common-checkboxIndicator']") 
filter_2[1].click()

# %%
#Creating lists for attributes
Brand_2=[]
Prd_desc=[]
Price_2 = []
n = 0

while True:
    time.sleep(3)
    for i in driver.find_elements_by_xpath("//div[@class= 'product-productMetaInfo']//h3[@class = 'product-brand']"):
        Brand_2.append(i.text)
        if len(Brand_2) == 100:
            break
    
    for i in driver.find_elements_by_xpath("//div[@class= 'product-productMetaInfo']//h4[@class = 'product-product']"):
        Prd_desc.append(i.text)
        if len(Prd_desc) == 100:
            break
    
    for i in driver.find_elements_by_xpath("//div[@class= 'product-productMetaInfo']//div[@class = 'product-price']"):
        Price_2.append(i.text)
        if len(Price_2) == 100:
            break
    
    if len(Price_2) == 100:
        break
            
    for j in driver.find_elements_by_xpath("//a[@rel = 'next']"):
        next_page_3=[j.get_attribute("href")]
    
    time.sleep(3)
        
    for n in next_page_3:
        driver.get(n) 
    

driver.close()

# %%
Price_2= [i.split('Rs. ')[1] for i in Price_2]

# %%
#Creating Dataframe
myntra_filtered_100_blackshoes = pd.DataFrame()
myntra_filtered_100_blackshoes["Brand"]=Brand_2
myntra_filtered_100_blackshoes["Product Description"]=Prd_desc
myntra_filtered_100_blackshoes["Price"]=Price_2

myntra_filtered_100_blackshoes
# Out:
#                    Brand                  Product Description  Price
# 0                   ALDO                Leather Solid Loafers  10499
# 1                   Puma        Men Jamming 2.0 Running Shoes  10399
# 2                   Nike        Men Zoom Span 4 Running Shoes   7195
# 3        PUMA Motorsport        Unisex Scuderia Ferrari Shoes   7999
# 4        PUMA Motorsport          Unisex Mercedes F1 Sneakers   7999
# 5                   ALDO                    Men Driving Shoes  11199
# 6   Heel & Buckle London                 Men Leather Sneakers   7693
# 7                   Puma       Men Deviate Nitro Running Shoe  11999
# 8        PUMA Motorsport       Unisex FerrariRS-Fast Sneakers   7999
# 9                   Puma                    Men Running Shoes   9749
# 10          Hush Puppies    Men Solid Leather Formal Slip-Ons   8099
# 11          UNDER ARMOUR       Men HOVR Sonic STRT Tech Shoes   9999
# 12                  Puma            Men Magnify Nitro Running  12999
# ...

# %% [markdown]
# # Q10: Go to webpage https://www.amazon.in/ Enter “Laptop” in the search field and then click the search icon. Then set CPU Type filter to “Intel Core i7” and “Intel Core i9” as shown in the below image:

# %%
driver = webdriver.Chrome(r"C:\Users\Gupta's\Downloads\chromedriver_win32/chromedriver.exe")

# %%
#Calling the driver to load the website
driver.get("https://www.amazon.in/")
driver.maximize_window()

#Searching the target webpage
Laptop_search = driver.find_element_by_xpath("//div[@class = 'nav-search-field ']/input[@type='text']")
Laptop_search.send_keys("Laptop")
search_btn = driver.find_element_by_xpath("//input[@id= 'nav-search-submit-button']")
search_btn.click()

# %%
#Applying filter for Intel Core i7
filter_1 = driver.find_elements_by_xpath("//ul[@aria-labelledby= 'p_n_feature_thirteen_browse-bin-title']//div[@class= 'a-checkbox a-checkbox-fancy s-navigation-checkbox aok-float-left']")
filter_1[-3].click()

# %%
#Creating lists for i7 dataframe
i7_title=[]
i7_ratings=[]
i7_price=[]

# %%
#Scraping data for i7
for i in driver.find_elements_by_xpath("//h2[@class= 'a-size-mini a-spacing-none a-color-base s-line-clamp-2']//a")[:10]:
        i7_title.append(i.text)
        
for i in driver.find_elements_by_xpath("//div[@class='a-row a-size-small']/span")[:20]:
        i7_ratings.append(i.get_attribute("aria-label"))
        
for i in driver.find_elements_by_xpath("//span[@class= 'a-price-whole']")[:10]:
        i7_price.append(i.text)
    
driver.close()

# %%
#i7 Rating Column contains extra information which is not needed in this assignment. Let's remove these
i7_Rating = []
for i in range(0,len(i7_ratings)):
    if i == 0 or  i/2 == i//2:
        i7_Rating.append(i7_ratings[i])

# %%
#Creating DataFrame for i7
Intel_Core_i7_10_Laptops=pd.DataFrame()
Intel_Core_i7_10_Laptops["Title"]=i7_title
Intel_Core_i7_10_Laptops["Price"]=i7_price
Intel_Core_i7_10_Laptops["Rating"]=i7_Rating

Intel_Core_i7_10_Laptops
# Out:
#                                                                                                                                                                                                       Title  \
# 0    LG Gram 16 Ultra-Light 11th Gen Core i5,8 GB RAM, 512 GB SSD, Win-10, Iris Xe Graphics, 16-inches (40.64 cms), Thunderbolt 4, USC -C x 2 (with Power), 1.19 kg, 3 Yr Warranty (16Z90P-G.AJ55A2, Black)
# 1    LG Gram 17 Ultra-Light 11th Gen Core i5,8 GB RAM, 512 GB SSD, Win-10, Iris Xe Graphics, 17-inches (43.18 cms), Thunderbolt 4, USC -C x 2 (with Power), 1.35 kg, 3 Yr Warranty (17Z90P-G.AJ55A2, Black)
# 2    ASUS TUF Gaming F15, 15.6-inch (39.62 cms) FHD 144Hz, Intel Core i5-10300H 10th Gen, GTX 1650 Ti GDDR6 4GB Graphics, Gaming Laptop (8GB RAM/512GB SSD/Windows 10/Fortress Gray/2.3 Kg), FX566LI-HN272T
# ...
